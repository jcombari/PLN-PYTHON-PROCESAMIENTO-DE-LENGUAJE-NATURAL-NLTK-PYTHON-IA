# %% [markdown]
# Vídeo: https://www.youtube.com/watch?v=awawNe1YaOs&list=PLaHpNulXyoOS_DMC4lzcfYYDaHJRSCw9G&index=3

# %% [raw]
# #EJEMPLO DE CONVERSIÓN TEXTO A VOZ (TTS) USANDO UN VOCODER PARA PERSONALIZAR LA VOZ
# #https://pysoundfile.readthedocs.io/en/0.9.0/
# #Trozos de código interesantes para trocear un fichero de audio y otras cosas...: https://pypi.org/project/SoundFile/
# #Más información: https://media.readthedocs.org/pdf/gtts/latest/gtts.pdf

# %%
#Importar librerías
import soundfile as sf
import pygame
import pyworld as pw
from gtts import gTTS
from tempfile import TemporaryFile
from pygame import mixer
from pydub import AudioSegment #pip install pydub
from os import path
import os
import matplotlib.pyplot as plt

# %%
#Convertir texto a audio mp3
tts = gTTS(text='Hola. ¿Cómo estás?', lang='es')
tts.save('hola.mp3')

# %%
os.getcwd() #get current dir
#os.path.basename("C:/Users/jenny/Documents/GITHUB/PLN-PYTHON-PROCESAMIENTO-DE-LENGUAJE-NATURAL-NLTK-PYTHON-IA/TTS/")
# Out:
# 'C:\\Users\\jenny\\Documents\\GITHUB\\PLN-PYTHON-PROCESAMIENTO-DE-LENGUAJE-NATURAL-NLTK-PYTHON-IA\\TTS'

# %%
path = r"C:\Users\jenny\Documents\GITHUB\PLN-PYTHON-PROCESAMIENTO-DE-LENGUAJE-NATURAL-NLTK-PYTHON-IA\TTS"
x = path.replace("\", "/")
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_33940/3716280876.py in <module>
#       1 path = r"C:\Users\jenny\Documents\GITHUB\PLN-PYTHON-PROCESAMIENTO-DE-LENGUAJE-NATURAL-NLTK-PYTHON-IA\TTS"
# ----> 2 x = path.replace("\", ""/")
#       3 print(x)
#
# TypeError: replace expected at least 2 arguments, got 1

# %%
# la librería pydub permite convertir el mp3 en .wav
sound = AudioSegment.from_mp3("hola.mp3")
sound.export("hola.wav", format="wav")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_33940/2767622592.py in <module>
#       1 # la librería pydub permite convertir el mp3 en .wav
# ----> 2 sound = AudioSegment.from_mp3("hola.mp3")
#
# ~\.conda\envs\research\lib\site-packages\pydub\audio_segment.py in from_mp3(cls, file, parameters)
#     794     @classmethod
#     795     def from_mp3(cls, file, parameters=None):
# --> 796         return cls.from_file(file, 'mp3', parameters=parameters)
#     797
#     798     @classmethod
#
# ~\.conda\envs\research\lib\site-packages\pydub\audio_segment.py in from_file(cls, file, format, codec, parameters, start_second, duration, **kwargs)
#     726             info = None
#     727         else:
# --> 728             info = mediainfo_json(orig_file, read_ahead_limit=read_ahead_limit)
#     729         if info:
# ...
