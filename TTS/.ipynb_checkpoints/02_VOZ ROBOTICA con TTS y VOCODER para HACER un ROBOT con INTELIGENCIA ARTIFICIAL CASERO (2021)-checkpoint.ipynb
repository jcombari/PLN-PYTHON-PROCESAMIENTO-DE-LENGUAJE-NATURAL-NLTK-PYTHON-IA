# %% [markdown]
# Vídeo: https://www.youtube.com/watch?v=awawNe1YaOs&list=PLaHpNulXyoOS_DMC4lzcfYYDaHJRSCw9G&index=3

# %% [raw]
# #EJEMPLO DE CONVERSIÓN TEXTO A VOZ (TTS) USANDO UN VOCODER PARA PERSONALIZAR LA VOZ
# #https://pysoundfile.readthedocs.io/en/0.9.0/
# #Trozos de código interesantes para trocear un fichero de audio y otras cosas...: https://pypi.org/project/SoundFile/
# #Más información: https://media.readthedocs.org/pdf/gtts/latest/gtts.pdf

# %%
#Importar librerías
import soundfile as sf
import pygame
import pyworld as pw
from gtts import gTTS
from tempfile import TemporaryFile
from pygame import mixer
from pydub import AudioSegment #pip install pydub
from pydub import silence, AudioSegment
from os import path
import os
import matplotlib.pyplot as plt
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.9.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# Para el error:
#
# C:\Users\jenny\.conda\envs\research\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
#
# Se debe escribir:
#
# * pip install ffmpeg-downloader
#
# * ffdl install --add-path

# %%
#Convertir texto a audio mp3
tts = gTTS(text='Hola. ¿Cómo estás?', lang='es')
tts.save('hola.mp3')

# %%
os.getcwd() #get current dir
#os.path.basename("C:/Users/jenny/Documents/GITHUB/PLN-PYTHON-PROCESAMIENTO-DE-LENGUAJE-NATURAL-NLTK-PYTHON-IA/TTS/")
# Out:
# 'C:\\Users\\jenny\\Documents\\GITHUB\\PLN-PYTHON-PROCESAMIENTO-DE-LENGUAJE-NATURAL-NLTK-PYTHON-IA\\TTS'

# %%
path = r'C:\\Users\\jenny\\Documents\\GITHUB\\PLN-PYTHON-PROCESAMIENTO-DE-LENGUAJE-NATURAL-NLTK-PYTHON-IA\\TTS'
#x = path.replace('\'', "/")
print(path)
# Out:
# C:\\Users\\jenny\\Documents\\GITHUB\\PLN-PYTHON-PROCESAMIENTO-DE-LENGUAJE-NATURAL-NLTK-PYTHON-IA\\TTS

# %%
# la librería pydub permite convertir el mp3 en .wav
sound = AudioSegment.from_mp3("C:\\Users\\jenny\\Documents\\GITHUB\\PLN-PYTHON-PROCESAMIENTO-DE-LENGUAJE-NATURAL-NLTK-PYTHON-IA\\TTS\\hola.mp3")
sound.export("hola.wav", format="wav")
# Out:
# <_io.BufferedRandom name='hola.wav'>

# %%
ficheroConLaVozModificada = 'C:\\IA\\holaVoc.wav'

# %%
ficheroConLaVozModificada = 'holaVoc.wav'
velocidadDelDiscurso=1.6 #cuanto mayor es el número, más rápido habla. 1->voz original. 
#OJO! Cuanto más rápido habla, más aguda suena la voz, así que hay que compensarlo con la gravedad
gravedad=5 #cuanto mayor es el número, más grave es la voz.1->voz original
atenuacionDelVolumen=1 #cuanto mayor es el número, más bajo se escucha la voz.1->voz original

# %%
x, fs = sf.read('hola.wav')
print('Número de muestras de audio:{0}'.format(len(x)))
plt.plot(x)
plt.ylabel('señal de voz')
plt.show()
# Out:
# Número de muestras de audio:47232

# %%
f0, sp, ap = pw.wav2world(x, fs)
print('Número de valores calulados de f0:{0} y ap:{1}'.format(len(f0), len(ap)))
print('Número de muestras usadas para calular f0 y ap:{0}'.format(len(x)/len(f0)))
plt.plot(f0)
plt.ylabel('pitch')
plt.show()
# Out:
# Número de valores calulados de f0:394 y ap:394
# Número de muestras usadas para calular f0 y ap:119.87817258883248

# %%
plt.plot(ap)
plt.ylabel('aperiodicidad')
plt.show()

# %%
plt.plot(sp)
plt.ylabel('espectrograma')
plt.show()

# %%
yy = pw.synthesize(f0/gravedad, sp/atenuacionDelVolumen, ap, fs/velocidadDelDiscurso, pw.default_frame_period)
sf.write(ficheroConLaVozModificada, yy, fs)

# %%
mixer.init()
mixer.music.load(ficheroConLaVozModificada)
print("Reproduciendo " + ficheroConLaVozModificada)
mixer.music.play()
while mixer.music.get_busy(): 
    pygame.time.Clock().tick(10)
mixer.quit()
# Out:
# Reproduciendo holaVoc.wav

# %%
os.remove(ficheroConLaVozModificada)
